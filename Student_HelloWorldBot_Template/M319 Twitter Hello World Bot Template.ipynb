# %% [markdown]
# # Create Your First Twitter Bot

# %% [markdown]
# ## In this notebook, you will create your first Twitter Bot. Here are some guidelines:
# * Any tweets you send will be visible to your teacher, your classmates, the Fremd community, and the broader Internet
#   * You are representing Fremd High School with any tweets you send
#   * Profanity, harassment, spamming, or any other misbehavior will result in a discipline referral and being reassigned a new project
#
# * Be careful not to accidentally spam Twitter users. Examples:
#   * Do not send _numerous_ unsolicited tweets to the same account
#   * Do not try to send the same tweet out over and over again
#   * Do not tweet more than once per minute
#     * Try _import time_, then use _time.sleep(60)_
#     * More information: https://pythonspot.com/sleep/
#     * Be wary of tweeting from for-loops and while-loops without using _time.sleep(60)_ in the loop

# %% [markdown]
# ### Step 1: Sign Up For a Twitter Account
#
# Follow the instructions below step-by-step without working ahead of the screenshots. First go to https://twitter.com/signup and fill in the information below using your D211 email address:

# %%
from IPython.display import Image
Image(filename="0_SignUp.png")

# %% [markdown]
# ### Step 2: Choose a School-Appropriate Username
#
# You can always change this later, but it must be unambiguously appropriate for all audiences.

# %%
from IPython.display import Image
Image(filename="1_Username.png")

# %% [markdown]
# ### Step 3: Enter Your Phone Number
#
# You should use your own phone number if you are comfortable using this, you have your phone with you, and you get signal in the computer lab. If not, you can use or create a free Google Voice account at https://voice.google.com or you can check with your teacher for other options.

# %%
from IPython.display import Image
Image(filename="2_Phone.png")

# %% [markdown]
# #### Step 4: Confirm Phone Number, Email Address, and Pick a Profile Picture
#
# Complete the following steps:
# * Confirm your phone number by typing in the code
# * Confirm your email address
# * Upload a school-appropriate profile picture
#   * The picture does NOT have to be of you
#   * This will help prevent you getting flagged as a spammer:
#   * https://www.buzzfeed.com/blakemontgomery/twitter-will-start-using-algorithms-to-crack-down-on-abusive?utm_term=.mrM4B91ZWr#.fj6wlJ6oEO

# %%
from IPython.display import Image
Image(filename="3_ConfirmEmail.png")

# %% [markdown]
# ### Step 5: Go to the Twitter Developers Site
#
# Go to https://dev.twitter.com so you can create your first app.

# %%
from IPython.display import Image
Image(filename="4_Developers.png")

# %% [markdown]
# ### Step 6: Create a New Twitter App
#
# Click the button "Create New App."

# %%
from IPython.display import Image
Image(filename="5_CreateNewApp.png")

# %% [markdown]
# ### Step 7: Name Your App
#
# Use the details listed below, but make sure to add a string of random numbers at the end of the Name category. Your app can't have the same name as another student's.

# %%
from IPython.display import Image
Image(filename="6_AppDetails.png")

# %% [markdown]
# ### Step 8: Save your API Key and API Secret
#
# An API key is what allows you to access your account securely through the API interface. Do not share it with anyone else, since this needs to be kept as secure as your username and password.

# %%
from IPython.display import Image
Image(filename="7_API_Key.png")

# %% [markdown]
# ### Step 9: Generate an Access Token
#
# You also need to generate an Access Token and Access Secret. If you are interested in the difference between an API Key/Secret and an Access Token/Secret, this is a nice little summary (these details go beyond the scope of the course): http://stackoverflow.com/questions/28057430/what-is-the-access-token-vs-access-token-secret-and-consumer-key-vs-consumer-s

# %%
from IPython.display import Image
Image(filename="8_API_Secret.png")

# %% [markdown]
# ### Task 1: Enter Your API (Consumer) Key/Secret and Access Token/Secret Below:
#
# This initializes the API object which allows us to send Tweets and perform other actions from our newly-created account:

# %%
# tweepy is a Python module for interacting with the Twitter API
import tweepy, time
 
#enter the corresponding information from your Twitter application:
CONSUMER_KEY = 'NeksNfxZpCprWyGAEQXsOR8Ji'#keep the quotes, replace this with your consumer key
CONSUMER_SECRET = 'sQgyIWgNRtLmzEOaNWRZoTXpiMspbVAdGIO5dAgqo9L0hpS1yK'#keep the quotes, replace this with your consumer secret key
ACCESS_TOKEN = '836991935478972417-6bRQ9K0R0GRmVa3d15hHZgaGg3HWt7c'#keep the quotes, replace this with your access token
ACCESS_SECRET = 'hVei5q1uKdYHfCeFp6fQaA3OSM217pszoxqF3K3aM2oi9'#keep the quotes, replace this with your access token secret
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tweepy.API(auth) #this creates the API object

# %% [markdown]
# ### Task 2: Send Your First Tweet
#
# First initialize the variable, *my_message*, to the string *"Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor"*
#
# Then call the following method to send your first tweet: *api.update_status(my_message)*
#
# Do not run this cell multiple times. You do not want your account to get locked out for suspected spamming or harassment.

# %%
my_message = "Mr. Tenopir's first name is Trevor?"

api.update_status(my_message)
# Out:
# Status(contributors=None, in_reply_to_user_id_str=None, source='AP CSP Project T', _api=<tweepy.api.API object at 0x05628C50>, retweeted=False, favorite_count=0, in_reply_to_status_id_str=None, lang='en', truncated=False, favorited=False, id_str='837713967514529792', geo=None, in_reply_to_screen_name=None, entities={'urls': [], 'user_mentions': [], 'hashtags': [], 'symbols': []}, id=837713967514529792, source_url='http://www.fhs.d211.org', place=None, in_reply_to_user_id=None, author=User(time_zone=None, is_translator=False, contributors_enabled=False, description='', entities={'description': {'urls': []}}, favourites_count=0, profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png', profile_link_color='1DA1F2', is_translation_enabled=False, _api=<tweepy.api.API object at 0x05628C50>, profile_use_background_image=True, notifications=False, statuses_count=2, name='YT', following=False, lang='en', profile_background_tile=False, default_
# ...

# %% [markdown]
# Take a look at all of the output above and scan for anything interesting. Then check Twitter and see if your first tweet went out to the world successfully!

# %% [markdown]
# ### Task 3: Tweeting Your First Picture
#
# Let's send a tweet with a picture attached. Find any JPEG picture and name it _picture1.jpg_, and save it to the folder containing this notebook. This picture should be 100% school appropriate.
#
# Now initialize a variable, *my_picture*, to the string _'picture1.jpg'_.
#
# Also intialize a variable, *my_status*, to a school-appropriate string of your choice. Remember that Twitter status updates cannot exceed 140 characters.
#
# Finally, send the tweet using the following method call: *api.update_with_media(my_picture,my_status)*

# %%
my_picture = 'picture1.jpg'
my_status = "Something went wrong here"

api.update_with_media(my_picture,my_status)
# Out:
# Status(contributors=None, in_reply_to_user_id_str=None, source='AP CSP Project T', _api=<tweepy.api.API object at 0x05628C50>, retweeted=False, favorite_count=0, in_reply_to_status_id_str=None, lang='en', truncated=False, favorited=False, id_str='837715378436521984', geo=None, in_reply_to_screen_name=None, entities={'urls': [], 'user_mentions': [], 'hashtags': [], 'symbols': [], 'media': [{'sizes': {'medium': {'w': 307, 'h': 164, 'resize': 'fit'}, 'large': {'w': 307, 'h': 164, 'resize': 'fit'}, 'small': {'w': 307, 'h': 164, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}, 'id': 837715376549003265, 'indices': [26, 49], 'expanded_url': 'https://twitter.com/tang1060/status/837715378436521984/photo/1', 'media_url_https': 'https://pbs.twimg.com/media/C6ApslIWAAE4GYu.jpg', 'display_url': 'pic.twitter.com/Oq9fWXUthH', 'url': 'https://t.co/Oq9fWXUthH', 'id_str': '837715376549003265', 'media_url': 'http://pbs.twimg.com/media/C6ApslIWAAE4GYu.jpg', 'type': 'photo'}]}, id=8377
# ...

# %% [markdown]
# ### Task 4: Searching Twitter
#
# Now search for the most recent tweets that mention the Fremd High School account, @fremdvikings:

# %%
#your search query is for @fremdvikings:
tweet_list = api.search(q="@fremdvikings")

#print out the text of the search results:
for tweet in tweet_list:
    print(tweet.text)
# Out:
# @FremdVikings Hello World
# @FremdVikings We are creating bots!!! #APCSP
# Mr. Grattoni is the best teacher at Fremd!! @FremdVikings
# @FremdVikings Hi.
# @FremdVikings, check this out! NASA released new open data! (Source: https://t.co/OkfCp95ds5) https://t.co/Vlg5RATi2s
# @FremdVikings 49 20 4c 6f 76 65 20 41 50 20 43 53 50
# @FremdVikings Hey
# @FremdVikings AP CSP is getting interesting...
# @FremdVikings AP CSP is lit
# @FremdVikings Fremd High School had its first graduation in 1968.
# RT @Arango2416: @FremdVikings gee wiz this class is cool!
# @FremdVikings Bots are awesome! #APCSP This tweet was generated by a bot #APCSP #FHSspirit #CSforall @AP_Trevor
# @FremdVikings, this is a pretty good experience in APCSP! Love this school!#APCSP, #FHSSpirit https://t.co/li8lJ9pEO3
# @FremdVikings gee wiz this class is cool!
# @FremdVikings Hello!

# %% [markdown]
# Find out how many tweets were in your search results using the following method call print(len(tweet_list)):

# %%
print(len(tweet_list))
# Out:
# 15

# %% [markdown]
# Try a few more searches using the following terms:
#
# * @FremdBot
# * #APCSP
# * #CSforall
# * at least two more school-appropriate searches
#
# Include each set of results in its own cell. Comment on anything interesting you found in a markdown cell after your code cells, or even reply to any tweets you think were meant for you.

# %%
tweet_list = api.search(q="@FremdBot")

for tweet in tweet_list:
    print(tweet.text)
# Out:
# @FremdBot I heard that Fremd APCSP students are creating their own Twitter bots! #APCSP #FHSSpirit #CSforall

# %%
tweet_list = api.search(q="#APCSP")

for tweet in tweet_list:
    print(tweet.text)
# Out:
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Im taking the #APcsp exam because APCSP is cool
# Go Vikes!! #APcsp
# I'm taking the #APCSP exam because I want AP Credits
# I'm taking the #APcsp exam because I want to save money and time
# @FremdVikings We are creating bots!!! #APCSP
# I'm taking the #APcsp exam because it's hard.
# I'm taking the #APcsp exam because I think it will prove to be helpful for my future.
# I'm taking the #APcsp exam because there is a full moon
# ...

# %%
tweet_list = api.search(q="#CSforall")

for tweet in tweet_list:
    print(tweet.text)
# Out:
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall @AP_Trevor
# Offer Computer Science in our public schools #CSforAll - Sign the Petition! https://t.co/zHhhCypxsM via @Change
# Hello World! This tweet was generated by a bot I created in #APCSP. #FHSspirit #CSforall
# I'm taking AP CSP because computers are great This tweet was generated by a bot #APCSP #FHSspirit #CSforall @AP_Trevor
# Hello World! This tweet was generated by a bot I created in #APCSP #FHSspirit #CSforall @AP_Trevor
# ...

# %%
tweet_list = api.search(q="@potato")

for tweet in tweet_list:
    print(tweet.text)
    
# Well that was a thing
# Out:
# 2013/09/16 Scott x CUTTセトリ
# @POTATO KID
#
# https://t.co/60yjV8L3pv #スコリバ
# #PotatoChamps $0's each w/ @Potato https://t.co/n0wKifoheo
# Chicken Cutlets with Oven Baked Purple and New Potatoes!!
#
# @Potato
# @chicken https://t.co/4PEE6v3qgr
# SUBSCRIBE TO ME ON YOUTUBE @POTATO MASTER24 #betacon17
# RT @heallaxie_102: Credits: 🎥 @shineeLips18_
# Props Mngr/Designer @Haille__
# Setting Mngr : @Potato
# Lastly, a special thanks to my sponsor…
# Credits: 🎥 @shineeLips18_
# Props Mngr/Designer @Haille__
# Setting Mngr : @Potato
# Lastly, a special thanks to my spo… https://t.co/fg4mpO0fNG
# More like MacReadytosurrender... via /r/fo4 @Potato-Chucker https://t.co/Zn8tcqdVlt

# %%
tweet_list = api.search(q="@kumo")

for tweet in tweet_list:
    print(tweet.text)
    
# figures
# Out:
# RT @kumo: I think I have a headache/flu/cold and I might have to stay home for the weekend... cough, cough #NintendoSwitch #ZeldaBreathofth…

# %% [markdown]
# ### Task 5: Send a few more Tweets.
#
# When you searched "@FremdBot", you might have found a tweet from "@FremdVikings" that mentioned this project. Send a reply by sending a tweet that begins "@FremdVikings". Please note that Mr. Tenopir will see these tweets.

# %%
api.update_status("@FremdVikings who wrote the hex digits? I don't want to bother decoding it myself. Initials are YT, pm me or something, ty in advance")
# Out:
# Status(contributors=None, in_reply_to_user_id_str='402862043', source='AP CSP Project T', _api=<tweepy.api.API object at 0x05628C50>, retweeted=False, favorite_count=0, in_reply_to_status_id_str=None, lang='en', truncated=False, favorited=False, id_str='837718904982155264', geo=None, in_reply_to_screen_name='FremdVikings', entities={'urls': [], 'user_mentions': [{'id_str': '402862043', 'id': 402862043, 'screen_name': 'FremdVikings', 'indices': [0, 13], 'name': 'Fremd High School'}], 'hashtags': [], 'symbols': []}, id=837718904982155264, source_url='http://www.fhs.d211.org', place=None, in_reply_to_user_id=402862043, author=User(time_zone=None, is_translator=False, contributors_enabled=False, description='', entities={'description': {'urls': []}}, favourites_count=0, profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png', profile_link_color='1DA1F2', is_translation_enabled=False, _api=<tweepy.api.API object at 0x05628C50>, profile_us
# ...

# %% [markdown]
# When you searched the hashtag #APcsp, you may have seen some tweets that began with "I'm taking the #APcsp exam because..."
#
# Send your own version of this tweet. Please remember that you will be representing Fremd High School with this tweet.

# %%
api.update_status("I am now specifically taking the #APCSP exam to find that guy who's after the full moon")
# Out:
# Status(contributors=None, in_reply_to_user_id_str=None, source='AP CSP Project T', _api=<tweepy.api.API object at 0x05628C50>, retweeted=False, favorite_count=0, in_reply_to_status_id_str=None, lang='en', truncated=False, favorited=False, id_str='837718920605941761', geo=None, in_reply_to_screen_name=None, entities={'urls': [], 'user_mentions': [], 'hashtags': [{'indices': [33, 39], 'text': 'APCSP'}], 'symbols': []}, id=837718920605941761, source_url='http://www.fhs.d211.org', place=None, in_reply_to_user_id=None, author=User(time_zone=None, is_translator=False, contributors_enabled=False, description='', entities={'description': {'urls': []}}, favourites_count=0, profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png', profile_link_color='1DA1F2', is_translation_enabled=False, _api=<tweepy.api.API object at 0x05628C50>, profile_use_background_image=True, notifications=False, statuses_count=5, name='YT', following=False, lang='en', p
# ...

# %% [markdown]
# ### Task 6: Briefly explore the documentation.
#
# Browse the following documentation for a few minutes:
#
# https://media.readthedocs.org/pdf/tweepy/v3.5.0/tweepy.pdf
#
# http://docs.tweepy.org/en/v3.5.0/

# %% [markdown]
# #### Give a brief description of what tweepy is and what it is used for.
#
# Your Answer: an API for python users to interect with Twitter that facilitates the process of connecting and communicating
# by handling authentication and providing various methods to interact with Twitter

# %%
api.get_status("")
# hmm...

# %% [markdown]
# ### Task 7: Continue to brainstorm. Build upon or come up with some new ideas you have for creating your own Twitter bot. Can you think of ways to incorporate image filters, web scraping, word clouds, the Google Maps API, or Open Data? Try to categorize your brainstorms as "big project (months of work)" and "feasible project (2 week project)."
#
# big project ideas (months of work): using visual clues such as level of light, surroundings, etc. and google maps determine where most tweets are sent from ( or just metadata if that's available, doubt it though)
#
# feasible project ideas (2 week project): search through tweets, whenever one mentions death send a message of condolences
# alternatively, whenever one it sent with a certain hashtag return a message. i.e, #NintendoSwitch return message = "Have Fun!"
# probably end up getting blocked within minutes though lol
